# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('./ch1ex1.csv')
points = df.values

# %%
xs = points[:, 0]
ys = points[:, 1]

#scatter plot
plt.figure
plt.scatter(xs, ys, c=labels)
plt.show()

# %%
df = pd.read_csv('./ch1ex1.csv')
points = df.values

new_df = pd.read_csv('./ch1ex2.csv')
new_points = new_df.values

# %%
from sklearn.cluster import KMeans
sy = KMeans(n_clusters=3)
sy.fit(points)
labels = sy.predict(points)
print(labels)
# Out:
# [2 0 1 1 0 0 1 2 0 0 1 2 0 1 0 2 1 1 2 1 0 2 0 2 2 0 2 2 2 0 1 1 1 0 2 0 2
#  2 0 2 2 1 0 0 0 2 2 1 2 1 1 1 2 2 2 0 2 2 0 1 0 2 2 1 1 0 1 0 0 2 1 0 1 2
#  1 0 2 2 2 1 2 0 1 0 0 0 0 2 2 1 0 1 0 2 2 2 1 0 0 1 0 2 0 1 2 1 1 1 0 0 2
#  0 1 0 0 0 2 0 1 1 2 2 2 2 2 0 1 2 0 0 1 1 0 2 0 2 1 0 1 2 1 1 2 1 1 2 1 0
#  2 2 2 1 1 0 1 0 2 2 1 0 1 1 1 0 2 2 0 1 1 2 2 1 2 2 0 2 1 1 1 2 2 1 2 1 1
#  2 0 1 2 2 2 2 0 1 2 0 0 0 2 0 2 2 0 1 1 2 1 2 2 0 0 2 1 0 1 2 1 0 2 0 0 0
#  0 1 1 1 2 2 0 2 1 0 2 2 0 2 1 1 1 1 1 0 2 2 1 1 2 0 1 0 0 2 2 0 0 0 2 1 2
#  0 2 1 1 1 1 1 2 2 0 2 2 0 1 1 0 2 1 1 0 0 2 2 2 0 0 2 1 0 0 1 2 2 2 0 2 2
#  2 0 0 0]

# %%
xs = new_points[:, 0]
ys = new_points[:, 1]

#scatter plot
plt.scatter(xs,ys, c=labels)
plt.show
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in _parse_scatter_color_args(c, edgecolors, kwargs, xsize, get_next_color_func)
#    4238             try:  # Is 'c' acceptable as PathCollection facecolors?
# -> 4239                 colors = mcolors.to_rgba_array(c)
#    4240             except ValueError:
#
# ~\anaconda3\lib\site-packages\matplotlib\colors.py in to_rgba_array(c, alpha)
#     339     else:
# --> 340         return np.array([to_rgba(cc, alpha) for cc in c])
#     341
#
# ~\anaconda3\lib\site-packages\matplotlib\colors.py in <listcomp>(.0)
#     339     else:
# --> 340         return np.array([to_rgba(cc, alpha) for cc in c])
#     341
#
# ~\anaconda3\lib\site-packages\matplotlib\colors.py in to_rgba(c, alpha)
#     184     if rgba is None:  # Suppress exception chaining of cache lookup failure.
# ...

# %%
sy = KMeans(n_clusters=3)
sy.fit(new_points)
labels = sy.predict(new_points)
print(labels)
# Out:
# [1 1 0 0 2 2 1 2 2 0 2 2 0 2 1 1 2 1 1 2 1 1 0 1 0 2 0 1 1 1 0 2 2 0 0 1 0
#  0 0 0 1 2 0 2 0 0 2 1 0 0 1 1 2 1 2 1 0 1 0 0 0 2 2 2 0 0 2 0 2 0 1 1 1 2
#  0 2 2 2 1 2 1 2 1 2 1 0 1 2 0 2 1 1 0 0 1 1 1 0 2 0]

# %%
centeriods = sy.cluster_centers_
centeriods_1= centeriods[:,0]
centeriods_2= centeriods[:,1]
plt.scatter(centeriods_1, centeriods_2)
plt.show()

# %%
centeriods = sy.cluster_centers_
centeriods_x= centeriods[:,0]
centeriods_y= centeriods[:,1]
plt.scatter(centeriods_1, centeriods_2, marker = 'X', s = 200)
plt.show()
